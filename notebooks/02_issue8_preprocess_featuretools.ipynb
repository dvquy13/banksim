# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

import seaborn as sns

# %%
# Custom modules

import sys
import os
ROOT_DIR = os.path.abspath('../')
sys.path.insert(0, ROOT_DIR + "/src")

# %% [markdown]
# # Constant

# %%
RAW_INPUT_PATH = '../data/raw/bs140513_032310.csv'
IGNORE_COLS = ['zipcodeOri', 'zipMerchant']

# %%
TEST_RATIO = 0.2

# %%
OUTPUT_DIR = '../data/process/'

# %%
LABEL = 'gender'

# %% [markdown]
# # Load input

# %%
raw_df = pd.read_csv(RAW_INPUT_PATH,
                     quotechar="'",
                     usecols=lambda c: c not in IGNORE_COLS)

# %% [markdown]
# # Clean

# %% [markdown]
# ## Drop noise (based on `01_eda` notebook)

# %% [markdown]
# ### In label `gender`

# %%
clean_df = raw_df.query('gender in ("F", "M")')

# %% [markdown]
# ### In label `age`

# %%
clean_df = clean_df.query('age != "U"')

# %% [markdown]
# # Divide train-test by customer

# %%
customer_list = clean_df['customer'].unique()

# %%
num_train_customer = round((1 - TEST_RATIO) * len(customer_list))
train_customer = np.random.choice(customer_list,
                                  size=num_train_customer,
                                  replace=False)
test_customer = set(customer_list) - set(train_customer)
test_customer = np.array(list(test_customer))

# %%
train_customer.shape
# Out:
# (3280,)

# %%
test_customer.shape
# Out:
# (820,)

# %%
train_df = clean_df.loc[clean_df['customer'].isin(train_customer)]
test_df = clean_df.loc[clean_df['customer'].isin(test_customer)]

# %%
train_df.shape
# Out:
# (472480, 8)

# %%
test_df.shape
# Out:
# (120470, 8)

# %% [markdown]
# # Featuretools

# %%
import featuretools as ft
import featuretools.variable_types as vtypes

# %%
train_df.reset_index(inplace=True)

# %%
es = ft.EntitySet(id='Transaction Logs')
variable_types = { 
      'step': vtypes.NumericTimeIndex,
      'age': vtypes.Categorical,
      'merchant': vtypes.Categorical,
      'category': vtypes.Categorical,
      'amount': vtypes.Numeric,
      'fraud': vtypes.Boolean}

# %%
es.entity_from_dataframe(entity_id='txn_logs', dataframe=train_df,
                         index='index', variable_types=variable_types)
# Out:
# Entityset: Transaction Logs
#   Entities:
#     txn_logs [Rows: 472480, Columns: 9]
#   Relationships:
#     No relationships

# %%
es.normalize_entity(base_entity_id='txn_logs',
                    new_entity_id='merchants',
                    index='merchant',
                    additional_variables=['category'])
# Out:
# Entityset: Transaction Logs
#   Entities:
#     txn_logs [Rows: 472480, Columns: 8]
#     merchants [Rows: 50, Columns: 2]
#   Relationships:
#     txn_logs.merchant -> merchants.merchant

# %%
es.normalize_entity(base_entity_id='txn_logs',
                    new_entity_id='customer_metadata',
                    index='customer',
                    additional_variables=['age'])
# Out:
# Entityset: Transaction Logs
#   Entities:
#     txn_logs [Rows: 472480, Columns: 7]
#     merchants [Rows: 50, Columns: 2]
#     customer_metadata [Rows: 3280, Columns: 2]
#   Relationships:
#     txn_logs.merchant -> merchants.merchant
#     txn_logs.customer -> customer_metadata.customer

# %%
es.normalize_entity(base_entity_id='txn_logs',
                    new_entity_id='customer_label',
                    index='customer',
                    additional_variables=['gender'])
# Out:
# Entityset: Transaction Logs
#   Entities:
#     txn_logs [Rows: 472480, Columns: 6]
#     merchants [Rows: 50, Columns: 2]
#     customer_metadata [Rows: 3280, Columns: 2]
#     customer_label [Rows: 3280, Columns: 2]
#   Relationships:
#     txn_logs.merchant -> merchants.merchant
#     txn_logs.customer -> customer_metadata.customer
#     txn_logs.customer -> customer_label.customer

# %%
feature_matrix, feature_names = ft.dfs(
    entityset=es, 
    target_entity='customer_metadata',
    max_depth=3,
    verbose=1,
    n_jobs=1,
    drop_exact=['gender'],
    ignore_entities=['customer_label'],
    ignore_variables={'customer':['customer']})
# Out:
# Built 111 features
# Elapsed: 00:16 | Progress: 100%|██████████

# %%
feature_matrix
# Out:
#             age  SUM(txn_logs.amount)  SUM(txn_logs.step)  \
# customer
# C1093826151   4               4716.20               14681
# C352968107    2               5519.77               15401
# C2054744914   4               2693.84                2494
# C757503768    5               4596.03               14099
# C1315400589   3               5739.56               15827
# ...          ..                   ...                 ...
# C650117238    3               2917.90                 963
# C2095815783   2               2854.58                9566
# C1014783484   1               2008.11               10407
# C849065220    4                390.57                 960
# C1809646275   3               1351.55                 740
#
#              STD(txn_logs.amount)  STD(txn_logs.step)  MAX(txn_logs.amount)  \
# customer
# C1093826151             18.035708           51.648467                 95.91
# C352968107              23.194176           52.222232                135.86
# C2054744914             35.455397           37.327340                189.59
# C757503768              23.550817           48.040350                168.45
# C1315400589             32.125813           51.752124                276.85
# ...                           ...                 ...                   ...
# C650117238             653.109788           39.449561               1914.56
# C2095815783             76.472538           22.942134                546.19
# C1014783484             19.191099           22.991109                 96.49
# C849065220              25.845704           22.872316                 93.98
# C1809646275            211.320958            7.382412                615.29
#
#              MAX(txn_logs.step)  SKEW(txn_logs.amount)  SKEW(txn_logs.step)  \
# customer
# C1093826151                 179               0.788957             0.042490
# C352968107                  179               1.390664            -0.055003
# C2054744914                 168               2.147027             2.202405
# C757503768                  179               1.851214            -0.053151
# C1315400589                 179               4.017118             0.003551
# ...                         ...                    ...                  ...
# C650117238                  169               2.440494             0.195306
# C2095815783                 177               5.283233            -0.505690
# C1014783484                 179               1.210393            -0.012028
# C849065220                  171               0.339886            -0.000005
# C1809646275                 152               1.329595            -2.075352
#
#              MIN(txn_logs.amount)  ...  \
# customer                           ...
# C1093826151                  0.44  ...
# C352968107                   0.53  ...
# C2054744914                  0.32  ...
# C757503768                   0.01  ...
# C1315400589                  0.27  ...
# ...                           ...  ...
# C650117238                  19.31  ...
# C2095815783                  0.90  ...
# C1014783484                  0.09  ...
# C849065220                  24.70  ...
# C1809646275                 64.76  ...
#
#              MEAN(txn_logs.merchants.STD(txn_logs.step))  \
# customer
# C1093826151                                    50.567665
# C352968107                                     48.790943
# C2054744914                                    48.978982
# C757503768                                     49.246813
# C1315400589                                    47.346242
# ...                                                  ...
# C650117238                                     51.639711
# C2095815783                                    50.646456
# C1014783484                                    47.868524
# C849065220                                     49.714011
# C1809646275                                    51.165072
#
#              MEAN(txn_logs.merchants.MIN(txn_logs.amount))  \
# customer
# C1093826151                                       0.006467
# C352968107                                        0.007278
# C2054744914                                       0.021692
# C757503768                                        0.011034
# C1315400589                                       0.008229
# ...                                                    ...
# C650117238                                        0.368750
# C2095815783                                       0.024118
# C1014783484                                       0.010946
# C849065220                                        1.171429
# C1809646275                                       0.854000
#
#              MEAN(txn_logs.merchants.MEAN(txn_logs.step))  \
# customer
# C1093826151                                     76.876088
# C352968107                                      94.075895
# C2054744914                                     91.432112
# C757503768                                      89.742316
# C1315400589                                    106.661550
# ...                                                   ...
# C650117238                                      77.685898
# C2095815783                                     76.620188
# C1014783484                                    103.496525
# C849065220                                      79.924462
# C1809646275                                     80.862903
#
#              MEAN(txn_logs.merchants.STD(txn_logs.amount))  \
# customer
# C1093826151                                      20.426210
# C352968107                                       21.450638
# C2054744914                                      42.584909
# C757503768                                       22.834724
# C1315400589                                      22.259138
# ...                                                    ...
# C650117238                                      365.352891
# C2095815783                                      33.964030
# C1014783484                                      20.590465
# C849065220                                      138.067776
# C1809646275                                     268.667207
#
#              MEAN(txn_logs.merchants.MIN(txn_logs.step))  \
# customer
# C1093826151                                     0.035928
# C352968107                                      0.017751
# C2054744914                                     0.061538
# C757503768                                      0.027586
# C1315400589                                     0.051429
# ...                                                  ...
# C650117238                                      0.000000
# C2095815783                                     0.044118
# C1014783484                                     0.000000
# C849065220                                      1.857143
# C1809646275                                     0.000000
#
#              MEAN(txn_logs.merchants.SUM(txn_logs.step))  \
# customer
# C1093826151                                 1.152764e+07
# C352968107                                  1.778805e+07
# C2054744914                                 1.323777e+07
# C757503768                                  1.606864e+07
# C1315400589                                 2.113912e+07
# ...                                                  ...
# C650117238                                  9.064425e+04
# C2095815783                                 1.066388e+07
# C1014783484                                 2.109699e+07
# C849065220                                  7.450457e+04
# C1809646275                                 1.022474e+05
#
#             MEAN(txn_logs.merchants.MAX(txn_logs.amount))  \
# customer
# C1093826151                                    158.128503
# C352968107                                     151.033195
# C2054744914                                    318.684769
# C757503768                                     163.170000
# C1315400589                                    142.158914
# ...                                                   ...
# C650117238                                    1975.906250
# C2095815783                                    235.705735
# C1014783484                                    135.159730
# C849065220                                     880.510000
# C1809646275                                   1441.558000
#
#              MEAN(txn_logs.merchants.SKEW(txn_logs.amount))  \
# customer
# C1093826151                                        0.801931
# C352968107                                         0.729204
# C2054744914                                        1.060497
# C757503768                                         0.791981
# C1315400589                                        0.626424
# ...                                                     ...
# C650117238                                         1.985177
# C2095815783                                        0.893096
# C1014783484                                        0.639952
# C849065220                                         2.419127
# C1809646275                                        1.189978
#
#             NUM_UNIQUE(txn_logs.merchants.MODE(txn_logs.customer))  \
# customer
# C1093826151                                                  7
# C352968107                                                  11
# C2054744914                                                 13
# C757503768                                                  14
# C1315400589                                                  7
# ...                                                        ...
# C650117238                                                   7
# C2095815783                                                  7
# C1014783484                                                  6
# C849065220                                                   5
# C1809646275                                                  3
#
#              MODE(txn_logs.merchants.MODE(txn_logs.customer))
# customer
# C1093826151                                        C747590731
# C352968107                                         C222098023
# C2054744914                                        C747590731
# C757503768                                         C747590731
# C1315400589                                        C222098023
# ...                                                       ...
# C650117238                                        C1978250683
# C2095815783                                        C747590731
# C1014783484                                        C222098023
# C849065220                                        C1275518867
# C1809646275                                       C1275518867
#
# [3280 rows x 111 columns]

# %%
feature_names
# Out:
# [<Feature: age>,
#  <Feature: SUM(txn_logs.amount)>,
#  <Feature: SUM(txn_logs.step)>,
#  <Feature: STD(txn_logs.amount)>,
#  <Feature: STD(txn_logs.step)>,
#  <Feature: MAX(txn_logs.amount)>,
#  <Feature: MAX(txn_logs.step)>,
#  <Feature: SKEW(txn_logs.amount)>,
#  <Feature: SKEW(txn_logs.step)>,
#  <Feature: MIN(txn_logs.amount)>,
#  <Feature: MIN(txn_logs.step)>,
#  <Feature: MEAN(txn_logs.amount)>,
#  <Feature: MEAN(txn_logs.step)>,
#  <Feature: COUNT(txn_logs)>,
#  <Feature: PERCENT_TRUE(txn_logs.fraud)>,
#  <Feature: NUM_UNIQUE(txn_logs.merchant)>,
#  <Feature: MODE(txn_logs.merchant)>,
#  <Feature: NUM_UNIQUE(txn_logs.merchants.category)>,
#  <Feature: MODE(txn_logs.merchants.category)>,
#  <Feature: SUM(txn_logs.merchants.COUNT(txn_logs))>,
#  <Feature: SUM(txn_logs.merchants.NUM_UNIQUE(txn_logs.customer))>,
#  <Feature: SUM(txn_logs.merchants.MAX(txn_logs.step))>,
#  <Feature: SUM(txn_logs.merchants.SKEW(txn_logs.step))>,
#  <Feature: SUM(txn_logs.merchants.MEAN(txn_logs.amount))>,
#  <Feature: SUM(txn_logs.merchants.PERCENT_TRUE(txn_logs.fraud))>,
#  <Feature: SUM(txn_logs.merchants.SUM(txn_logs.amount))>,
#  <Feature: SUM(txn_logs.merchants.STD(txn_logs.step))>,
#  <Feature: SUM(txn_logs.merchants.MIN(txn_logs.amount))>,
#  <Feature: SUM(txn_logs.merchants.MEAN(txn_logs.step))>,
#  <Feature: SUM(txn_logs.merchants.STD(txn_logs.amount))>,
#  <Feature: SUM(txn_logs.merchants.MIN(txn_logs.step))>,
#  <Feature: SUM(txn_logs.merchants.SUM(txn_logs.step))>,
#  <Feature: SUM(txn_logs.merchants.MAX(txn_logs.amount))>,
#  <Feature: SUM(txn_logs.merchants.SKEW(txn_logs.amount))>,
#  <Feature: STD(txn_logs.merchants.COUNT(txn_logs))>,
#  <Feature: STD(txn_logs.merchants.NUM_UNIQUE(txn_logs.customer))>,
#  <Feature: STD(txn_logs.merchants.MAX(txn_logs.step))>,
#  <Feature: STD(txn_logs.merchants.SKEW(txn_logs.step))>,
#  <Feature: STD(txn_logs.merchants.MEAN(txn_logs.amount))>,
#  <Feature: STD(txn_logs.merchants.PERCENT_TRUE(txn_logs.fraud))>,
#  <Feature: STD(txn_logs.merchants.SUM(txn_logs.amount))>,
#  <Feature: STD(txn_logs.merchants.STD(txn_logs.step))>,
#  <Feature: STD(txn_logs.merchants.MIN(txn_logs.amount))>,
#  <Feature: STD(txn_logs.merchants.MEAN(txn_logs.step))>,
#  <Feature: STD(txn_logs.merchants.STD(txn_logs.amount))>,
#  <Feature: STD(txn_logs.merchants.MIN(txn_logs.step))>,
#  <Feature: STD(txn_logs.merchants.SUM(txn_logs.step))>,
#  <Feature: STD(txn_logs.merchants.MAX(txn_logs.amount))>,
#  <Feature: STD(txn_logs.merchants.SKEW(txn_logs.amount))>,
#  <Feature: MAX(txn_logs.merchants.COUNT(txn_logs))>,
#  <Feature: MAX(txn_logs.merchants.NUM_UNIQUE(txn_logs.customer))>,
#  <Feature: MAX(txn_logs.merchants.MAX(txn_logs.step))>,
#  <Feature: MAX(txn_logs.merchants.SKEW(txn_logs.step))>,
#  <Feature: MAX(txn_logs.merchants.MEAN(txn_logs.amount))>,
#  <Feature: MAX(txn_logs.merchants.PERCENT_TRUE(txn_logs.fraud))>,
#  <Feature: MAX(txn_logs.merchants.SUM(txn_logs.amount))>,
#  <Feature: MAX(txn_logs.merchants.STD(txn_logs.step))>,
#  <Feature: MAX(txn_logs.merchants.MIN(txn_logs.amount))>,
#  <Feature: MAX(txn_logs.merchants.MEAN(txn_logs.step))>,
#  <Feature: MAX(txn_logs.merchants.STD(txn_logs.amount))>,
#  <Feature: MAX(txn_logs.merchants.MIN(txn_logs.step))>,
#  <Feature: MAX(txn_logs.merchants.SUM(txn_logs.step))>,
#  <Feature: MAX(txn_logs.merchants.MAX(txn_logs.amount))>,
#  <Feature: MAX(txn_logs.merchants.SKEW(txn_logs.amount))>,
#  <Feature: SKEW(txn_logs.merchants.COUNT(txn_logs))>,
#  <Feature: SKEW(txn_logs.merchants.NUM_UNIQUE(txn_logs.customer))>,
#  <Feature: SKEW(txn_logs.merchants.MAX(txn_logs.step))>,
#  <Feature: SKEW(txn_logs.merchants.SKEW(txn_logs.step))>,
#  <Feature: SKEW(txn_logs.merchants.MEAN(txn_logs.amount))>,
#  <Feature: SKEW(txn_logs.merchants.PERCENT_TRUE(txn_logs.fraud))>,
#  <Feature: SKEW(txn_logs.merchants.SUM(txn_logs.amount))>,
#  <Feature: SKEW(txn_logs.merchants.STD(txn_logs.step))>,
#  <Feature: SKEW(txn_logs.merchants.MIN(txn_logs.amount))>,
#  <Feature: SKEW(txn_logs.merchants.MEAN(txn_logs.step))>,
#  <Feature: SKEW(txn_logs.merchants.STD(txn_logs.amount))>,
#  <Feature: SKEW(txn_logs.merchants.MIN(txn_logs.step))>,
#  <Feature: SKEW(txn_logs.merchants.SUM(txn_logs.step))>,
#  <Feature: SKEW(txn_logs.merchants.MAX(txn_logs.amount))>,
#  <Feature: SKEW(txn_logs.merchants.SKEW(txn_logs.amount))>,
#  <Feature: MIN(txn_logs.merchants.COUNT(txn_logs))>,
#  <Feature: MIN(txn_logs.merchants.NUM_UNIQUE(txn_logs.customer))>,
#  <Feature: MIN(txn_logs.merchants.MAX(txn_logs.step))>,
#  <Feature: MIN(txn_logs.merchants.SKEW(txn_logs.step))>,
#  <Feature: MIN(txn_logs.merchants.MEAN(txn_logs.amount))>,
#  <Feature: MIN(txn_logs.merchants.PERCENT_TRUE(txn_logs.fraud))>,
#  <Feature: MIN(txn_logs.merchants.SUM(txn_logs.amount))>,
#  <Feature: MIN(txn_logs.merchants.STD(txn_logs.step))>,
#  <Feature: MIN(txn_logs.merchants.MIN(txn_logs.amount))>,
#  <Feature: MIN(txn_logs.merchants.MEAN(txn_logs.step))>,
#  <Feature: MIN(txn_logs.merchants.STD(txn_logs.amount))>,
#  <Feature: MIN(txn_logs.merchants.MIN(txn_logs.step))>,
#  <Feature: MIN(txn_logs.merchants.SUM(txn_logs.step))>,
#  <Feature: MIN(txn_logs.merchants.MAX(txn_logs.amount))>,
#  <Feature: MIN(txn_logs.merchants.SKEW(txn_logs.amount))>,
#  <Feature: MEAN(txn_logs.merchants.COUNT(txn_logs))>,
#  <Feature: MEAN(txn_logs.merchants.NUM_UNIQUE(txn_logs.customer))>,
#  <Feature: MEAN(txn_logs.merchants.MAX(txn_logs.step))>,
#  <Feature: MEAN(txn_logs.merchants.SKEW(txn_logs.step))>,
#  <Feature: MEAN(txn_logs.merchants.MEAN(txn_logs.amount))>,
#  <Feature: MEAN(txn_logs.merchants.PERCENT_TRUE(txn_logs.fraud))>,
#  <Feature: MEAN(txn_logs.merchants.SUM(txn_logs.amount))>,
#  <Feature: MEAN(txn_logs.merchants.STD(txn_logs.step))>,
#  <Feature: MEAN(txn_logs.merchants.MIN(txn_logs.amount))>,
#  <Feature: MEAN(txn_logs.merchants.MEAN(txn_logs.step))>,
#  <Feature: MEAN(txn_logs.merchants.STD(txn_logs.amount))>,
#  <Feature: MEAN(txn_logs.merchants.MIN(txn_logs.step))>,
#  <Feature: MEAN(txn_logs.merchants.SUM(txn_logs.step))>,
#  <Feature: MEAN(txn_logs.merchants.MAX(txn_logs.amount))>,
#  <Feature: MEAN(txn_logs.merchants.SKEW(txn_logs.amount))>,
#  <Feature: NUM_UNIQUE(txn_logs.merchants.MODE(txn_logs.customer))>,
#  <Feature: MODE(txn_logs.merchants.MODE(txn_logs.customer))>]

# %%
train_df
# Out:
#          index  step     customer age gender     merchant           category  \
# 0            0     0  C1093826151   4      M   M348934600  es_transportation
# 1            1     0   C352968107   2      M   M348934600  es_transportation
# 2            2     0  C2054744914   4      F  M1823072687  es_transportation
# 3            4     0   C757503768   5      M   M348934600  es_transportation
# 4            5     0  C1315400589   3      F   M348934600  es_transportation
# ...        ...   ...          ...  ..    ...          ...                ...
# 472475  594637   179   C748358246   2      M  M1823072687  es_transportation
# 472476  594638   179  C1753498738   3      F  M1823072687  es_transportation
# 472477  594639   179   C650108285   4      F  M1823072687  es_transportation
# 472478  594640   179   C123623130   2      F   M349281107         es_fashion
# 472479  594641   179  C1499363341   5      M  M1823072687  es_transportation
#
#         amount  fraud
# 0         4.55      0
# 1        39.68      0
# 2        26.89      0
# 3        35.72      0
# 4        25.81      0
# ...        ...    ...
# 472475   51.17      0
# 472476   20.53      0
# 472477   50.73      0
# 472478   22.44      0
# 472479   14.46      0
#
# [472480 rows x 9 columns]

# %%
feature_matrix_enc, features_enc = ft.encode_features(
    feature_matrix, feature_names)

# %%
feature_matrix_enc
# Out:
#              age = 2  age = 3  age = 4  age = 5  age = 1  age = 6  age = 0  \
# customer
# C1093826151        0        0        1        0        0        0        0
# C352968107         1        0        0        0        0        0        0
# C2054744914        0        0        1        0        0        0        0
# C757503768         0        0        0        1        0        0        0
# C1315400589        0        1        0        0        0        0        0
# ...              ...      ...      ...      ...      ...      ...      ...
# C650117238         0        1        0        0        0        0        0
# C2095815783        1        0        0        0        0        0        0
# C1014783484        0        0        0        0        1        0        0
# C849065220         0        0        1        0        0        0        0
# C1809646275        0        1        0        0        0        0        0
#
#              age is unknown  SUM(txn_logs.step)  SUM(txn_logs.amount)  ...  \
# customer                                                               ...
# C1093826151               0               14681               4716.20  ...
# C352968107                0               15401               5519.77  ...
# C2054744914               0                2494               2693.84  ...
# C757503768                0               14099               4596.03  ...
# C1315400589               0               15827               5739.56  ...
# ...                     ...                 ...                   ...  ...
# C650117238                0                 963               2917.90  ...
# C2095815783               0                9566               2854.58  ...
# C1014783484               0               10407               2008.11  ...
# C849065220                0                 960                390.57  ...
# C1809646275               0                 740               1351.55  ...
#
#              MODE(txn_logs.merchant) = M1741626453  \
# customer
# C1093826151                                      0
# C352968107                                       0
# C2054744914                                      0
# C757503768                                       0
# C1315400589                                      0
# ...                                            ...
# C650117238                                       0
# C2095815783                                      0
# C1014783484                                      0
# C849065220                                       0
# C1809646275                                      0
#
#              MODE(txn_logs.merchant) is unknown  \
# customer
# C1093826151                                   0
# C352968107                                    0
# C2054744914                                   0
# C757503768                                    0
# C1315400589                                   0
# ...                                         ...
# C650117238                                    0
# C2095815783                                   0
# C1014783484                                   0
# C849065220                                    0
# C1809646275                                   0
#
#              NUM_UNIQUE(txn_logs.merchants.category)  \
# customer
# C1093826151                                        5
# C352968107                                        10
# C2054744914                                        6
# C757503768                                         8
# C1315400589                                        6
# ...                                              ...
# C650117238                                         6
# C2095815783                                        5
# C1014783484                                        5
# C849065220                                         4
# C1809646275                                        3
#
#              MODE(txn_logs.merchants.category) = es_transportation  \
# customer
# C1093826151                                                  1
# C352968107                                                   1
# C2054744914                                                  1
# C757503768                                                   1
# C1315400589                                                  1
# ...                                                        ...
# C650117238                                                   0
# C2095815783                                                  1
# C1014783484                                                  1
# C849065220                                                   0
# C1809646275                                                  0
#
#              MODE(txn_logs.merchants.category) = es_health  \
# customer
# C1093826151                                              0
# C352968107                                               0
# C2054744914                                              0
# C757503768                                               0
# C1315400589                                              0
# ...                                                    ...
# C650117238                                               0
# C2095815783                                              0
# C1014783484                                              0
# C849065220                                               0
# C1809646275                                              0
#
#              MODE(txn_logs.merchants.category) = es_wellnessandbeauty  \
# customer
# C1093826151                                                  0
# C352968107                                                   0
# C2054744914                                                  0
# C757503768                                                   0
# C1315400589                                                  0
# ...                                                        ...
# C650117238                                                   0
# C2095815783                                                  0
# C1014783484                                                  0
# C849065220                                                   0
# C1809646275                                                  0
#
#              MODE(txn_logs.merchants.category) = es_sportsandtoys  \
# customer
# C1093826151                                                  0
# C352968107                                                   0
# C2054744914                                                  0
# C757503768                                                   0
# C1315400589                                                  0
# ...                                                        ...
# C650117238                                                   1
# C2095815783                                                  0
# C1014783484                                                  0
# C849065220                                                   1
# C1809646275                                                  0
#
#              MODE(txn_logs.merchants.category) = es_fashion  \
# customer
# C1093826151                                               0
# C352968107                                                0
# C2054744914                                               0
# C757503768                                                0
# C1315400589                                               0
# ...                                                     ...
# C650117238                                                0
# C2095815783                                               0
# C1014783484                                               0
# C849065220                                                0
# C1809646275                                               0
#
#              MODE(txn_logs.merchants.category) = es_home  \
# customer
# C1093826151                                            0
# C352968107                                             0
# C2054744914                                            0
# C757503768                                             0
# C1315400589                                            0
# ...                                                  ...
# C650117238                                             0
# C2095815783                                            0
# C1014783484                                            0
# C849065220                                             0
# C1809646275                                            1
#
#              MODE(txn_logs.merchants.category) is unknown
# customer
# C1093826151                                             0
# C352968107                                              0
# C2054744914                                             0
# C757503768                                              0
# C1315400589                                             0
# ...                                                   ...
# C650117238                                              0
# C2095815783                                             0
# C1014783484                                             0
# C849065220                                              0
# C1809646275                                             0
#
# [3280 rows x 45 columns]

# %%
features_enc
# Out:
# [<Feature: age = 2>,
#  <Feature: age = 3>,
#  <Feature: age = 4>,
#  <Feature: age = 5>,
#  <Feature: age = 1>,
#  <Feature: age = 6>,
#  <Feature: age = 0>,
#  <Feature: age is unknown>,
#  <Feature: SUM(txn_logs.step)>,
#  <Feature: SUM(txn_logs.amount)>,
#  <Feature: STD(txn_logs.step)>,
#  <Feature: STD(txn_logs.amount)>,
#  <Feature: MAX(txn_logs.step)>,
#  <Feature: MAX(txn_logs.amount)>,
#  <Feature: SKEW(txn_logs.step)>,
#  <Feature: SKEW(txn_logs.amount)>,
#  <Feature: MIN(txn_logs.step)>,
#  <Feature: MIN(txn_logs.amount)>,
#  <Feature: MEAN(txn_logs.step)>,
#  <Feature: MEAN(txn_logs.amount)>,
#  <Feature: COUNT(txn_logs)>,
#  <Feature: NUM_UNIQUE(txn_logs.fraud)>,
#  <Feature: NUM_UNIQUE(txn_logs.merchant)>,
#  <Feature: MODE(txn_logs.fraud) = 0>,
#  <Feature: MODE(txn_logs.fraud) = 1>,
#  <Feature: MODE(txn_logs.fraud) is unknown>,
#  <Feature: MODE(txn_logs.merchant) = M1823072687>,
#  <Feature: MODE(txn_logs.merchant) = M348934600>,
#  <Feature: MODE(txn_logs.merchant) = M480139044>,
#  <Feature: MODE(txn_logs.merchant) = M1535107174>,
#  <Feature: MODE(txn_logs.merchant) = M547558035>,
#  <Feature: MODE(txn_logs.merchant) = M980657600>,
#  <Feature: MODE(txn_logs.merchant) = M1198415165>,
#  <Feature: MODE(txn_logs.merchant) = M692898500>,
#  <Feature: MODE(txn_logs.merchant) = M2122776122>,
#  <Feature: MODE(txn_logs.merchant) = M1741626453>,
#  <Feature: MODE(txn_logs.merchant) is unknown>,
#  <Feature: NUM_UNIQUE(txn_logs.merchants.category)>,
#  <Feature: MODE(txn_logs.merchants.category) = es_transportation>,
#  <Feature: MODE(txn_logs.merchants.category) = es_health>,
#  <Feature: MODE(txn_logs.merchants.category) = es_wellnessandbeauty>,
#  <Feature: MODE(txn_logs.merchants.category) = es_sportsandtoys>,
#  <Feature: MODE(txn_logs.merchants.category) = es_fashion>,
#  <Feature: MODE(txn_logs.merchants.category) = es_home>,
#  <Feature: MODE(txn_logs.merchants.category) is unknown>]

# %% [markdown]
# #### Generate label

# %%
_tmp = es['customer_label'].df.copy()
_tmp.drop(columns=['customer'], inplace=True)

agg_train_df = feature_matrix_enc.join(_tmp, how='left')

# %% [markdown]
# # Apply same transformation to test

# %%
test_df.reset_index(inplace=True)

# %%
es_test = ft.EntitySet(id='Transaction Logs')
variable_types = { 
      'step': vtypes.NumericTimeIndex,
      'age': vtypes.Categorical,
      'merchant': vtypes.Categorical,
      'category': vtypes.Categorical,
      'amount': vtypes.Numeric,
      'fraud': vtypes.Categorical}

# %%
es_test.entity_from_dataframe(entity_id='txn_logs', dataframe=test_df,
                              index='index', variable_types=variable_types)
# Out:
# Entityset: Transaction Logs
#   Entities:
#     txn_logs [Rows: 120470, Columns: 10]
#   Relationships:
#     No relationships

# %%
es_test.normalize_entity(base_entity_id='txn_logs',
                         new_entity_id='merchants',
                         index='merchant',
                         additional_variables=['category'])
# Out:
# Entityset: Transaction Logs
#   Entities:
#     txn_logs [Rows: 120470, Columns: 9]
#     merchants [Rows: 49, Columns: 2]
#   Relationships:
#     txn_logs.merchant -> merchants.merchant

# %%
es_test.normalize_entity(base_entity_id='txn_logs',
                         new_entity_id='customer_metadata',
                         index='customer',
                         additional_variables=['age'])
# Out:
# Entityset: Transaction Logs
#   Entities:
#     txn_logs [Rows: 120470, Columns: 8]
#     merchants [Rows: 49, Columns: 2]
#     customer_metadata [Rows: 820, Columns: 2]
#   Relationships:
#     txn_logs.merchant -> merchants.merchant
#     txn_logs.customer -> customer_metadata.customer

# %%
es_test.normalize_entity(base_entity_id='txn_logs',
                         new_entity_id='customer_label',
                         index='customer',
                         additional_variables=['gender'])
# Out:
# Entityset: Transaction Logs
#   Entities:
#     txn_logs [Rows: 120470, Columns: 7]
#     merchants [Rows: 49, Columns: 2]
#     customer_metadata [Rows: 820, Columns: 2]
#     customer_label [Rows: 820, Columns: 2]
#   Relationships:
#     txn_logs.merchant -> merchants.merchant
#     txn_logs.customer -> customer_metadata.customer
#     txn_logs.customer -> customer_label.customer

# %%
feature_matrix_test = ft.calculate_feature_matrix(features=features_enc,
                                                  entities=['txn_logs', 'merchants',
                                                            'customer_metadata'],
                                                  entityset=es_test)

# %%
feature_matrix_test
# Out:
#              age = 2  age = 3  age = 4  age = 5  age = 1  age = 6  age = 0  \
# customer
# C1760612790    False     True    False    False    False    False    False
# C202531238     False    False     True    False    False    False    False
# C39858251      False    False    False     True    False    False    False
# C98707741      False    False     True    False    False    False    False
# C623601481     False     True    False    False    False    False    False
# ...              ...      ...      ...      ...      ...      ...      ...
# C1455309687    False    False     True    False    False    False    False
# C197543842     False    False     True    False    False    False    False
# C1404665203    False    False    False    False     True    False    False
# C1555447628     True    False    False    False    False    False    False
# C478503155      True    False    False    False    False    False    False
#
#              age is unknown  SUM(txn_logs.step)  SUM(txn_logs.amount)  ...  \
# customer                                                               ...
# C1760612790           False               15303               5187.93  ...
# C202531238            False               15328               4942.43  ...
# C39858251             False               11747               4208.52  ...
# C98707741             False               13208               4635.87  ...
# C623601481            False               12094               8335.52  ...
# ...                     ...                 ...                   ...  ...
# C1455309687           False                9435               4996.16  ...
# C197543842            False                3159               2011.93  ...
# C1404665203           False                 593                877.45  ...
# C1555447628           False               14100               4400.99  ...
# C478503155            False               13468               3265.73  ...
#
#              MODE(txn_logs.merchant) = M1741626453  \
# customer
# C1760612790                                  False
# C202531238                                   False
# C39858251                                    False
# C98707741                                    False
# C623601481                                   False
# ...                                            ...
# C1455309687                                  False
# C197543842                                   False
# C1404665203                                  False
# C1555447628                                  False
# C478503155                                   False
#
#              MODE(txn_logs.merchant) is unknown  \
# customer
# C1760612790                               False
# C202531238                                False
# C39858251                                 False
# C98707741                                 False
# C623601481                                False
# ...                                         ...
# C1455309687                               False
# C197543842                                False
# C1404665203                                True
# C1555447628                               False
# C478503155                                False
#
#              NUM_UNIQUE(txn_logs.merchants.category)  \
# customer
# C1760612790                                        8
# C202531238                                         7
# C39858251                                          7
# C98707741                                          9
# C623601481                                         8
# ...                                              ...
# C1455309687                                        9
# C197543842                                         8
# C1404665203                                        4
# C1555447628                                        8
# C478503155                                         8
#
#              MODE(txn_logs.merchants.category) = es_transportation  \
# customer
# C1760612790                                               True
# C202531238                                                True
# C39858251                                                 True
# C98707741                                                 True
# C623601481                                                True
# ...                                                        ...
# C1455309687                                               True
# C197543842                                                True
# C1404665203                                              False
# C1555447628                                               True
# C478503155                                                True
#
#              MODE(txn_logs.merchants.category) = es_health  \
# customer
# C1760612790                                          False
# C202531238                                           False
# C39858251                                            False
# C98707741                                            False
# C623601481                                           False
# ...                                                    ...
# C1455309687                                          False
# C197543842                                           False
# C1404665203                                           True
# C1555447628                                          False
# C478503155                                           False
#
#              MODE(txn_logs.merchants.category) = es_wellnessandbeauty  \
# customer
# C1760612790                                              False
# C202531238                                               False
# C39858251                                                False
# C98707741                                                False
# C623601481                                               False
# ...                                                        ...
# C1455309687                                              False
# C197543842                                               False
# C1404665203                                              False
# C1555447628                                              False
# C478503155                                               False
#
#              MODE(txn_logs.merchants.category) = es_sportsandtoys  \
# customer
# C1760612790                                              False
# C202531238                                               False
# C39858251                                                False
# C98707741                                                False
# C623601481                                               False
# ...                                                        ...
# C1455309687                                              False
# C197543842                                               False
# C1404665203                                              False
# C1555447628                                              False
# C478503155                                               False
#
#              MODE(txn_logs.merchants.category) = es_fashion  \
# customer
# C1760612790                                           False
# C202531238                                            False
# C39858251                                             False
# C98707741                                             False
# C623601481                                            False
# ...                                                     ...
# C1455309687                                           False
# C197543842                                            False
# C1404665203                                           False
# C1555447628                                           False
# C478503155                                            False
#
#              MODE(txn_logs.merchants.category) = es_home  \
# customer
# C1760612790                                        False
# C202531238                                         False
# C39858251                                          False
# C98707741                                          False
# C623601481                                         False
# ...                                                  ...
# C1455309687                                        False
# C197543842                                         False
# C1404665203                                        False
# C1555447628                                        False
# C478503155                                         False
#
#              MODE(txn_logs.merchants.category) is unknown
# customer
# C1760612790                                         False
# C202531238                                          False
# C39858251                                           False
# C98707741                                           False
# C623601481                                          False
# ...                                                   ...
# C1455309687                                         False
# C197543842                                          False
# C1404665203                                         False
# C1555447628                                         False
# C478503155                                          False
#
# [820 rows x 45 columns]

# %% [markdown]
# #### Generate label

# %%
_tmp = es_test['customer_label'].df.copy()
_tmp.drop(columns=['customer'], inplace=True)

agg_test_df = feature_matrix_test.join(_tmp, how='left')

# %% [markdown]
# # Persist

# %%
agg_train_df.to_csv(OUTPUT_DIR + "/train_data_fe3.csv", index=False)
agg_test_df.to_csv(OUTPUT_DIR + "/test_data_fe3.csv", index=False)

# %% [markdown]
# # Archive
